# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#membaca dan print isi file csv terlebih dahulu
df = pd.read_csv('international footbal results from 1872 to 2022.csv')
df
# Out:
#              date  home_team    away_team  home_score  away_score  \
# 0      1872-11-30   Scotland      England           0           0
# 1      1873-03-08    England     Scotland           4           2
# 2      1874-03-07   Scotland      England           2           1
# 3      1875-03-06    England     Scotland           2           2
# 4      1876-03-04   Scotland      England           3           0
# ...           ...        ...          ...         ...         ...
# 44348  2022-12-14   Thailand       Taiwan           0           1
# 44349  2022-12-14    Vietnam  Philippines           1           0
# 44350  2022-12-17    Croatia      Morocco           2           1
# 44351  2022-12-17  Singapore     Maldives           3           1
# 44352  2022-12-18  Argentina       France           3           3
#
#            tournament          city    country  neutral
# 0            Friendly       Glasgow   Scotland    False
# 1            Friendly        London    England    False
# ...

# %%
#mengeluarkan nama negara dari kolom 'country' dan menghitung jumlahnya
country = df['country'].value_counts()
#print 6 negara dengan jumlah terbanyak
country.head(6)
# Out:
# United States    1262
# France            830
# Malaysia          755
# England           722
# Sweden            660
# Qatar             633
# Name: country, dtype: int64

# %%
#mengeluarkan jenis turnamen dari kolom 'tournament' dan menghitung jumlahnya
tournament = df['tournament'].value_counts()
#print 6 jenis turnamen dengan jumlah terbanyak
tournament.head(6)
# Out:
# Friendly                                17519
# FIFA World Cup qualification             7878
# UEFA Euro qualification                  2585
# African Cup of Nations qualification     1932
# FIFA World Cup                            964
# Copa América                              841
# Name: tournament, dtype: int64
